# %% [markdown]
# <a href="https://colab.research.google.com/github/etherealnatsu/coop/blob/main/easy_view_and_graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/etherealnatsu/coop.git
# Out:
# Cloning into 'coop'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 9 (delta 0), reused 3 (delta 0), pack-reused 6
# Receiving objects: 100% (9/9), 90.27 MiB | 28.59 MiB/s, done.

# %% [markdown]
# run the top command to get the data from github

# %%
import pandas as pd

# %% [markdown]
# you can work with pandas now.

# %%
data = '/content/coop/audience.xlsx'
read= pd.read_excel(data)
read
# Out:
#                Brand/Company Name  \
# 0     Choose your advertiser name
# 1     Choose your advertiser name
# 2     Choose your advertiser name
# 3     Choose your advertiser name
# 4     Choose your advertiser name
# ...                           ...
# 1422  Choose your advertiser name
# 1423  Choose your advertiser name
# 1424  Choose your advertiser name
# 1425  Choose your advertiser name
# 1426  Choose your advertiser name
#
#                                        Audience Segment Audience List Type  \
# 0     In-Market Categories » Real Estate » Residenti...    Custom Audience
# 1     In-Market Categories » Autos & Vehicles » Moto...    Custom Audience
# 2     In-Market Categories » Autos & Vehicles » Moto...    Custom Audience
# 3     In-Market Categories » Travel » Trips by Desti...    Custom Audience
# 4     In-Market Categories » Real Estate » Residenti...    Custom Audience
# ...                                                 ...                ...
# ...

# %% [markdown]
# play them to view the data

# %% [markdown]
# this is to view audience file

# %%
data='/content/coop/device_creative.xlsx'
read=pd.read_excel(data)
read
# Out:
#                                               Strategy  \
# 0                     Mobile_2P_Custom Intent/Affinity
# 1                                           Mobile_RON
# 2                     Mobile_2P_Custom Intent/Affinity
# 3       Mobile_2P_Pixel Converters_Optimized Targeting
# 4                     Mobile_2P_Custom Intent/Affinity
# ...                                                ...
# 464428  Mobile_2P_Pixel Converters_Optimized Targeting
# 464429                                      Mobile_RON
# 464430                Mobile_2P_Custom Intent/Affinity
# 464431                                      Mobile_RON
# 464432                                      Mobile_RON
#
#                                    DMA Name        Browser Operating System  \
# 0                 Abilene-Sweetwater, Texas  Google Chrome     Android 13.0
# 1                           Albany, Georgia  Google Chrome      Android 5.1
# ...

# %% [markdown]
# this is to view device_creative file

# %%
data='/content/coop/inventory.xlsx'
read=pd.read_excel(data)
read

# %% [markdown]
# this is to view inventory file
